# %%
import tensorflow as tf

# %%
import tensorflow_datasets as tfds

# %%
(ds_test, ds_val, ds_train), ds_info = tfds.load(
    'mnist',
    split=['test', 'train[0%:17%]', 'train[17%:]'],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)

# %%
len(ds_train), len(ds_val), len(ds_test)
# Out:
# (49800, 10200, 10000)

# %%
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255., label

# %%
ds_train = ds_train.map(
    normalize_img, 
    num_parallel_calls=tf.data.AUTOTUNE
)

ds_train = ds_train.cache()
ds_train = ds_train.shuffle(len(ds_train))
ds_train = ds_train.batch(128)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

# %%
ds_val = ds_val.map(
    normalize_img, 
    num_parallel_calls=tf.data.AUTOTUNE
)

ds_val = ds_val.cache()
ds_val = ds_val.batch(128)
ds_val = ds_val.prefetch(tf.data.AUTOTUNE)

# %%
ds_test = ds_test.map(
    normalize_img, 
    num_parallel_calls=tf.data.AUTOTUNE
)

ds_test = ds_test.cache()
ds_test = ds_test.batch(128)
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %%
history = []

# %%
# Using a basic network

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(384, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

model.summary()
# Out:
# /Users/ziegler/Documents/code_projects/ai/u7/.venv/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 384)            │       301,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 352,010 (1.34 MB)
#  Trainable params: 352,010 (1.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# %%
history.append(('Basic DNN', model.fit(
    ds_train,
    epochs=25,
    validation_data=ds_val,
)))
# Out:
# Epoch 1/25
# 2025-03-21 14:36:47.973633: I tensorflow/core/kernels/data/tf_record_dataset_op.cc:387] The default buffer size is 262144, which is overridden by the user specified `buffer_size` of 8388608
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.5036 - sparse_categorical_accuracy: 0.8567 - val_loss: 0.1455 - val_sparse_categorical_accuracy: 0.9557
# Epoch 2/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1110 - sparse_categorical_accuracy: 0.9677 - val_loss: 0.1164 - val_sparse_categorical_accuracy: 0.9650
# Epoch 3/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0674 - sparse_categorical_accuracy: 0.9799 - val_loss: 0.0959 - val_sparse_categorical_accuracy: 0.9706
# Epoch 4/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0465 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.0761 - val_sparse_categorical_accuracy: 0.9779
# Epoch 5/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0332 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.0854 - val_sparse_categorical_accuracy: 0.9770
# Epoch 6/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0229 - sparse_categorical_accuracy: 0.9931 - val_loss: 0.0879 - val_sparse_categorical_accuracy: 0.9760
# Epoch 7/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0187 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0797 - val_sparse_categorical_accuracy: 0.9787
# Epoch 8/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.0951 - val_sparse_categorical_accuracy: 0.9758
# Epoch 9/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0162 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0890 - val_sparse_categorical_accuracy: 0.9775
# Epoch 10/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0084 - sparse_categorical_accuracy: 0.9975 - val_loss: 0.1001 - val_sparse_categorical_accuracy: 0.9760
# Epoch 11/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0110 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0989 - val_sparse_categorical_accuracy: 0.9798
# Epoch 12/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0088 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0979 - val_sparse_categorical_accuracy: 0.9771
# Epoch 13/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.1037 - val_sparse_categorical_accuracy: 0.9786
# Epoch 14/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0068 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.1050 - val_sparse_categorical_accuracy: 0.9782
# Epoch 15/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0062 - sparse_categorical_accuracy: 0.9977 - val_loss: 0.1157 - val_sparse_categorical_accuracy: 0.9757
# Epoch 16/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9959 - val_loss: 0.0938 - val_sparse_categorical_accuracy: 0.9811
# Epoch 17/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0114 - sparse_categorical_accuracy: 0.9964 - val_loss: 0.1162 - val_sparse_categorical_accuracy: 0.9778
# Epoch 18/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0071 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.1114 - val_sparse_categorical_accuracy: 0.9795
# Epoch 19/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.1103 - val_sparse_categorical_accuracy: 0.9793
# Epoch 20/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0065 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.1236 - val_sparse_categorical_accuracy: 0.9776
# Epoch 21/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0070 - sparse_categorical_accuracy: 0.9978 - val_loss: 0.1104 - val_sparse_categorical_accuracy: 0.9807
# Epoch 22/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0044 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.1141 - val_sparse_categorical_accuracy: 0.9810
# Epoch 23/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.1357 - val_sparse_categorical_accuracy: 0.9773
# Epoch 24/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0116 - sparse_categorical_accuracy: 0.9966 - val_loss: 0.1647 - val_sparse_categorical_accuracy: 0.9718
# Epoch 25/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0148 - sparse_categorical_accuracy: 0.9954 - val_loss: 0.1094 - val_sparse_categorical_accuracy: 0.9810

# %%
# Using regularization

# %%
del model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(
        384, 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.L2(0.005),
    ),
    tf.keras.layers.Dense(
        128, 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.L2(0.005),
    ),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 384)            │       301,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        49,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 352,010 (1.34 MB)
#  Trainable params: 352,010 (1.34 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history.append(('Basic DNN reg.', model.fit(
    ds_train,
    epochs=25,
    validation_data=ds_val,
)))
# Out:
# Epoch 1/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9489 - sparse_categorical_accuracy: 0.8488 - val_loss: 0.5328 - val_sparse_categorical_accuracy: 0.9308
# Epoch 2/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4843 - sparse_categorical_accuracy: 0.9347 - val_loss: 0.4149 - val_sparse_categorical_accuracy: 0.9419
# Epoch 3/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4009 - sparse_categorical_accuracy: 0.9455 - val_loss: 0.4026 - val_sparse_categorical_accuracy: 0.9415
# Epoch 4/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3715 - sparse_categorical_accuracy: 0.9492 - val_loss: 0.3717 - val_sparse_categorical_accuracy: 0.9415
# Epoch 5/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3385 - sparse_categorical_accuracy: 0.9547 - val_loss: 0.3318 - val_sparse_categorical_accuracy: 0.9554
# Epoch 6/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3190 - sparse_categorical_accuracy: 0.9571 - val_loss: 0.3193 - val_sparse_categorical_accuracy: 0.9555
# Epoch 7/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3018 - sparse_categorical_accuracy: 0.9600 - val_loss: 0.2972 - val_sparse_categorical_accuracy: 0.9614
# Epoch 8/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2891 - sparse_categorical_accuracy: 0.9623 - val_loss: 0.2899 - val_sparse_categorical_accuracy: 0.9593
# Epoch 9/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2760 - sparse_categorical_accuracy: 0.9636 - val_loss: 0.2953 - val_sparse_categorical_accuracy: 0.9589
# Epoch 10/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2684 - sparse_categorical_accuracy: 0.9646 - val_loss: 0.2625 - val_sparse_categorical_accuracy: 0.9639
# Epoch 11/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2578 - sparse_categorical_accuracy: 0.9662 - val_loss: 0.2615 - val_sparse_categorical_accuracy: 0.9643
# Epoch 12/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2569 - sparse_categorical_accuracy: 0.9640 - val_loss: 0.2664 - val_sparse_categorical_accuracy: 0.9600
# Epoch 13/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2489 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.2516 - val_sparse_categorical_accuracy: 0.9626
# Epoch 14/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2379 - sparse_categorical_accuracy: 0.9686 - val_loss: 0.2463 - val_sparse_categorical_accuracy: 0.9643
# Epoch 15/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2403 - sparse_categorical_accuracy: 0.9669 - val_loss: 0.2698 - val_sparse_categorical_accuracy: 0.9557
# Epoch 16/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2401 - sparse_categorical_accuracy: 0.9666 - val_loss: 0.2363 - val_sparse_categorical_accuracy: 0.9667
# Epoch 17/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2243 - sparse_categorical_accuracy: 0.9706 - val_loss: 0.2364 - val_sparse_categorical_accuracy: 0.9655
# Epoch 18/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2244 - sparse_categorical_accuracy: 0.9689 - val_loss: 0.2446 - val_sparse_categorical_accuracy: 0.9593
# Epoch 19/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2282 - sparse_categorical_accuracy: 0.9664 - val_loss: 0.2271 - val_sparse_categorical_accuracy: 0.9644
# Epoch 20/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2097 - sparse_categorical_accuracy: 0.9722 - val_loss: 0.2414 - val_sparse_categorical_accuracy: 0.9620
# Epoch 21/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2162 - sparse_categorical_accuracy: 0.9696 - val_loss: 0.2352 - val_sparse_categorical_accuracy: 0.9612
# Epoch 22/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2025 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.2217 - val_sparse_categorical_accuracy: 0.9661
# Epoch 23/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1982 - sparse_categorical_accuracy: 0.9738 - val_loss: 0.2284 - val_sparse_categorical_accuracy: 0.9642
# Epoch 24/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2057 - sparse_categorical_accuracy: 0.9704 - val_loss: 0.2124 - val_sparse_categorical_accuracy: 0.9687
# Epoch 25/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1984 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.2120 - val_sparse_categorical_accuracy: 0.9687

# %%
# Longer training with regularization

# %%
del model

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(
        384, 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.L2(0.01),
    ),
    tf.keras.layers.Dense(
        128, 
        activation='relu',
        kernel_regularizer=tf.keras.regularizers.L2(0.01),
    ),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# %%
history.append(('DNN reg. long training.', model.fit(
    ds_train,
    epochs=25,
    validation_data=ds_val,
)))
# Out:
# Epoch 1/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9216 - sparse_categorical_accuracy: 0.8333 - val_loss: 0.5978 - val_sparse_categorical_accuracy: 0.9134
# Epoch 2/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5740 - sparse_categorical_accuracy: 0.9188 - val_loss: 0.5200 - val_sparse_categorical_accuracy: 0.9219
# Epoch 3/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5033 - sparse_categorical_accuracy: 0.9299 - val_loss: 0.4823 - val_sparse_categorical_accuracy: 0.9277
# Epoch 4/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4629 - sparse_categorical_accuracy: 0.9344 - val_loss: 0.4798 - val_sparse_categorical_accuracy: 0.9193
# Epoch 5/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4423 - sparse_categorical_accuracy: 0.9364 - val_loss: 0.4284 - val_sparse_categorical_accuracy: 0.9365
# Epoch 6/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4016 - sparse_categorical_accuracy: 0.9452 - val_loss: 0.4242 - val_sparse_categorical_accuracy: 0.9319
# Epoch 7/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3890 - sparse_categorical_accuracy: 0.9469 - val_loss: 0.3945 - val_sparse_categorical_accuracy: 0.9410
# Epoch 8/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3795 - sparse_categorical_accuracy: 0.9481 - val_loss: 0.3617 - val_sparse_categorical_accuracy: 0.9483
# Epoch 9/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3578 - sparse_categorical_accuracy: 0.9486 - val_loss: 0.3458 - val_sparse_categorical_accuracy: 0.9520
# Epoch 10/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3381 - sparse_categorical_accuracy: 0.9533 - val_loss: 0.3337 - val_sparse_categorical_accuracy: 0.9541
# Epoch 11/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3327 - sparse_categorical_accuracy: 0.9550 - val_loss: 0.3500 - val_sparse_categorical_accuracy: 0.9431
# Epoch 12/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3349 - sparse_categorical_accuracy: 0.9519 - val_loss: 0.3210 - val_sparse_categorical_accuracy: 0.9541
# Epoch 13/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3094 - sparse_categorical_accuracy: 0.9557 - val_loss: 0.3162 - val_sparse_categorical_accuracy: 0.9552
# Epoch 14/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2989 - sparse_categorical_accuracy: 0.9594 - val_loss: 0.3019 - val_sparse_categorical_accuracy: 0.9573
# Epoch 15/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2921 - sparse_categorical_accuracy: 0.9603 - val_loss: 0.2931 - val_sparse_categorical_accuracy: 0.9580
# Epoch 16/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2950 - sparse_categorical_accuracy: 0.9576 - val_loss: 0.3000 - val_sparse_categorical_accuracy: 0.9544
# Epoch 17/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2853 - sparse_categorical_accuracy: 0.9602 - val_loss: 0.2909 - val_sparse_categorical_accuracy: 0.9568
# Epoch 18/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2755 - sparse_categorical_accuracy: 0.9613 - val_loss: 0.2851 - val_sparse_categorical_accuracy: 0.9580
# Epoch 19/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2698 - sparse_categorical_accuracy: 0.9624 - val_loss: 0.2900 - val_sparse_categorical_accuracy: 0.9550
# Epoch 20/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2705 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.2799 - val_sparse_categorical_accuracy: 0.9587
# Epoch 21/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2675 - sparse_categorical_accuracy: 0.9623 - val_loss: 0.2740 - val_sparse_categorical_accuracy: 0.9597
# Epoch 22/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2562 - sparse_categorical_accuracy: 0.9653 - val_loss: 0.2634 - val_sparse_categorical_accuracy: 0.9625
# Epoch 23/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2619 - sparse_categorical_accuracy: 0.9617 - val_loss: 0.2646 - val_sparse_categorical_accuracy: 0.9624
# Epoch 24/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2486 - sparse_categorical_accuracy: 0.9657 - val_loss: 0.2770 - val_sparse_categorical_accuracy: 0.9527
# Epoch 25/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2516 - sparse_categorical_accuracy: 0.9635 - val_loss: 0.2577 - val_sparse_categorical_accuracy: 0.9615

# %%
model.evaluate(ds_test)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2441 - sparse_categorical_accuracy: 0.9668
# [0.24479438364505768, 0.9656999707221985]

# %%
# Using a Convolutional Neural Network

# %%
del model

# %%
model = tf.keras.Sequential(
    [
        tf.keras.Input(shape=(28, 28, 1)),
        tf.keras.layers.Conv2D(
            32, 
            kernel_size=(3, 3), 
            activation="relu"
        ),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Conv2D(
            64, 
            kernel_size=(3, 3), 
            activation="relu"
        ),
        tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(10, activation="linear"),
    ]
)

model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 10)             │        16,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,826 (136.04 KB)
#  Trainable params: 34,826 (136.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# %%
history.append(('CNN', model.fit(
    ds_train,
    epochs=25,
    validation_data=ds_val,
)))
# Out:
# Epoch 1/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.7901 - sparse_categorical_accuracy: 0.7587 - val_loss: 0.1109 - val_sparse_categorical_accuracy: 0.9670
# Epoch 2/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.1290 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.0709 - val_sparse_categorical_accuracy: 0.9796
# Epoch 3/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - loss: 0.0889 - sparse_categorical_accuracy: 0.9734 - val_loss: 0.0587 - val_sparse_categorical_accuracy: 0.9828
# Epoch 4/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0734 - sparse_categorical_accuracy: 0.9778 - val_loss: 0.0519 - val_sparse_categorical_accuracy: 0.9854
# Epoch 5/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0629 - sparse_categorical_accuracy: 0.9808 - val_loss: 0.0485 - val_sparse_categorical_accuracy: 0.9850
# Epoch 6/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0576 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.0500 - val_sparse_categorical_accuracy: 0.9857
# Epoch 7/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0563 - sparse_categorical_accuracy: 0.9818 - val_loss: 0.0431 - val_sparse_categorical_accuracy: 0.9868
# Epoch 8/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9840 - val_loss: 0.0410 - val_sparse_categorical_accuracy: 0.9880
# Epoch 9/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0490 - sparse_categorical_accuracy: 0.9841 - val_loss: 0.0392 - val_sparse_categorical_accuracy: 0.9893
# Epoch 10/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0447 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.0398 - val_sparse_categorical_accuracy: 0.9893
# Epoch 11/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9870 - val_loss: 0.0376 - val_sparse_categorical_accuracy: 0.9892
# Epoch 12/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0384 - sparse_categorical_accuracy: 0.9877 - val_loss: 0.0375 - val_sparse_categorical_accuracy: 0.9893
# Epoch 13/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0362 - sparse_categorical_accuracy: 0.9882 - val_loss: 0.0358 - val_sparse_categorical_accuracy: 0.9902
# Epoch 14/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0357 - sparse_categorical_accuracy: 0.9883 - val_loss: 0.0362 - val_sparse_categorical_accuracy: 0.9907
# Epoch 15/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.0353 - val_sparse_categorical_accuracy: 0.9906
# Epoch 16/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0313 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.0394 - val_sparse_categorical_accuracy: 0.9890
# Epoch 17/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0320 - sparse_categorical_accuracy: 0.9899 - val_loss: 0.0354 - val_sparse_categorical_accuracy: 0.9899
# Epoch 18/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0302 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.0365 - val_sparse_categorical_accuracy: 0.9907
# Epoch 19/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0306 - sparse_categorical_accuracy: 0.9896 - val_loss: 0.0355 - val_sparse_categorical_accuracy: 0.9913
# Epoch 20/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0287 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.0332 - val_sparse_categorical_accuracy: 0.9913
# Epoch 21/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0252 - sparse_categorical_accuracy: 0.9924 - val_loss: 0.0343 - val_sparse_categorical_accuracy: 0.9914
# Epoch 22/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0257 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.0338 - val_sparse_categorical_accuracy: 0.9916
# Epoch 23/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0249 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.0342 - val_sparse_categorical_accuracy: 0.9913
# Epoch 24/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.0349 - val_sparse_categorical_accuracy: 0.9908
# Epoch 25/25
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - loss: 0.0245 - sparse_categorical_accuracy: 0.9917 - val_loss: 0.0344 - val_sparse_categorical_accuracy: 0.9916

# %%
model.evaluate(ds_test)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0241 - sparse_categorical_accuracy: 0.9929
# [0.02348913438618183, 0.9925000071525574]

# %%
# History

# %%
history
# Out:
# [('Basic DNN', <keras.src.callbacks.history.History at 0x150232410>),
#  ('Basic DNN reg.', <keras.src.callbacks.history.History at 0x15ec8de70>),
#  ('DNN reg. long training.',
#   <keras.src.callbacks.history.History at 0x176207d00>),
#  ('CNN', <keras.src.callbacks.history.History at 0x176fcbe50>)]

# %%
hist_elements = list(history[0][1].history.keys())
hist_elements
# Out:
# ['loss',
#  'sparse_categorical_accuracy',
#  'val_loss',
#  'val_sparse_categorical_accuracy']

# %%
import matplotlib.pyplot as plt

# %%
for i in hist_elements:
    print(i)
    for j in history:
        plt.plot(range(len(j[1].history[i])), j[1].history[i], label=j[0])
        plt.legend()
    plt.show()
# Out:
# loss
# sparse_categorical_accuracy
# val_loss
# val_sparse_categorical_accuracy
